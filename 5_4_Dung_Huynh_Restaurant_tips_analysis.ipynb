# %% [markdown]
# # **🍽️ Restaurant Tips Analysis**

# %% [markdown]
# ![restaurant.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This project aims to use the restaurant tips dataset to practice creating composition plots and visualizations. We will examine the relationship between different variables and the tips given.

# %% [markdown]
# The dataset consists of information from 244 restaurant bills, collected in the US in 1987.

# %% [markdown]
# It includes details about the tips given to restaurant staff, such as the total bill, tip amount, gender of the person paying, smoking status, day of the week, time of day, and party size.

# %% [markdown]
# ## **👣 The First Steps**

# %% [markdown]
# ### **📥 Data import**

# %% [markdown]
# First, let's import the needed libraries: Pandas & Matplotlib.

# %%
# PUT YOUR CODE HERE
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Then load data from the following link: https://raw.githubusercontent.com/RusAbk/sca_datasets/main/tips.csv

# %%
# PUT YOUR CODE HERE
df= pd.read_csv('https://raw.githubusercontent.com/RusAbk/sca_datasets/main/tips.csv')

# %% [markdown]
# ### **🔍 Data exploration**

# %% [markdown]
# #### **Test sample**

# %% [markdown]
# Let's take a look at the first 5 rows to be sure, that data is loaded properly:

# %%
# PUT YOUR CODE HERE
df.head()
# Out:
#    id  total_bill   tip     sex smoker  day    time  size
# 0   0       16.99  1.01  Female     No  Sun  Dinner     2
# 1   1       10.34  1.66    Male     No  Sun  Dinner     3
# 2   2       21.01  3.50    Male     No  Sun  Dinner     3
# 3   3       23.68  3.31    Male     No  Sun  Dinner     2
# 4   4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# > 🎉 Great! It seems to be okay.
#
# As you can see each observation represents a customer who left a tip at a restaurant.
#
# We can see information about:
# * the day it occurred
# * if it was at lunch or dinner
# * the total bill
# * the sex of the person
# * if they were a smoker or not
# * the size of the party
#
# Before continuing take a look at a few rows of the data and use `info` and `describe` to analyze dataset column types and values.

# %% [markdown]
# #### **Column types checking**

# %% [markdown]
# Show the columns of the dataframe and their types:

# %%
# PUT YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          244 non-null    Int64
#  1   total_bill  244 non-null    Float64
#  2   tip         244 non-null    Float64
#  3   sex         244 non-null    string
#  4   smoker      244 non-null    string
#  5   day         244 non-null    string
#  6   time        244 non-null    string
#  7   size        244 non-null    Int64
# dtypes: Float64(2), Int64(2), string(4)
# memory usage: 16.3 KB

# %% [markdown]
# > **Ooops... 🤔**
# >
# > We have string columns considered as objects.
#
# ![image.png](data:image/png;base64,...)
#
# Let's fix their types and make them string:

# %%
# PUT YOUR CODE HERE
df = df.convert_dtypes()

# %% [markdown]
# Check again (output columns and their types):

# %%
# PUT YOUR CODE HERE
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          244 non-null    Int64
#  1   total_bill  244 non-null    Float64
#  2   tip         244 non-null    Float64
#  3   sex         244 non-null    string
#  4   smoker      244 non-null    string
#  5   day         244 non-null    string
#  6   time        244 non-null    string
#  7   size        244 non-null    Int64
# dtypes: Float64(2), Int64(2), string(4)
# memory usage: 16.3 KB

# %% [markdown]
# Nice! We finished this. Look like we are ready to explore some statistics on the given data.

# %% [markdown]
# #### **Basic descriptive statistics**

# %% [markdown]
# Show a descriptive statistics of the numeric columns:

# %%
# PUT YOUR CODE HERE
df.describe()
# Out:
#               id  total_bill       tip      size
# count      244.0       244.0     244.0     244.0
# mean       121.5   19.785943  2.998279  2.569672
# std    70.580923    8.902412  1.383638    0.9511
# min          0.0        3.07       1.0       1.0
# 25%        60.75     13.3475       2.0       2.0
# 50%        121.5      17.795       2.9       2.0
# 75%       182.25     24.1275    3.5625       3.0
# max        243.0       50.81      10.0       6.0

# %% [markdown]
# Great! Now we know a little more about our data.
#
# ➡️ Let's move forward!

# %% [markdown]
# ## **💸 Tip value influencers**

# %% [markdown]
# ### **🚬 Do people who smoke give more tips?**

# %% [markdown]
# Let's figure out the difference between smokers and non-smokers in terms of their behavior and purchasing habits in public catering establishments.

# %% [markdown]
# #### **Separate smokers and non-smokers**

# %% [markdown]
# Create a new dataframe `smokers_df` containing only info about smokers.

# %%
smokers_df= df[df.smoker== 'Yes']

# %% [markdown]
# Check whether everything is okay. Output a test sample (5 random rows):

# %%
smokers_df.sample(5)
# Out:
#       id  total_bill   tip     sex smoker   day    time  size
# 106  106       20.49  4.06    Male    Yes   Sat  Dinner     2
# 72    72       26.86  3.14  Female    Yes   Sat  Dinner     2
# 173  173       31.85  3.18    Male    Yes   Sun  Dinner     2
# 204  204       20.53   4.0    Male    Yes  Thur   Lunch     4
# 192  192       28.44  2.56    Male    Yes  Thur   Lunch     2

# %% [markdown]
# Also create another one dataframe `non_smokers_df` containing only non-smokers.

# %%
non_smokers_df=df[df.smoker== 'No']

# %% [markdown]
# Check whether everything is okay. Output a test sample (5 random rows):

# %%
non_smokers_df.sample(5)
# Out:
#       id  total_bill   tip     sex smoker  day    time  size
# 57    57       26.41   1.5  Female     No  Sat  Dinner     2
# 50    50       12.54   2.5    Male     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 104  104       20.92  4.08  Female     No  Sat  Dinner     2
# 27    27       12.69   2.0    Male     No  Sat  Dinner     2

# %% [markdown]
# #### **Compare their measures of central tendency**

# %% [markdown]
# As we know, measures of central tendency is one of the basic tools, that allow us to compare different datasets as it shows the most typical values.

# %% [markdown]
# ##### **🌏 Whole dataset**

# %% [markdown]
# Let's try to calculate measures of central tendency for the whole dataset first.
#
# Calculate them for the **'tip'** column through the whole dataset and save them into the following variables:
#
# * min => `common_tip_min`
# * max => `common_tip_max`
# * mean => `common_tip_mean`
# * median => `common_tip_median`

# %%
common_tip_min= df.tip.min()
common_tip_max= df.tip.max()
common_tip_mean= df.tip.mean()
common_tip_median= df.tip.median()

# %% [markdown]
# Let's show the resulting values for whole dataset (we already have the code written for you 😉)

# %%
# Make a list of values
common_values = [common_tip_min, common_tip_max, common_tip_mean, common_tip_median]
# Round all the values to 4 decimal places
common_values = map(lambda x: round(x, 4), common_values)

# Make a dataframe from the list
common_mct = pd.DataFrame(common_values, index=['min', 'max', 'mean', 'median'])
# Output the dataframe
common_mct
# Out:
#               0
# min      1.0000
# max     10.0000
# mean     2.9983
# median   2.9000

# %% [markdown]
# ##### **🚬 Smokers**

# %% [markdown]
# Do the same taking into account only smokers. Use the following variables:
#
# * min => `smokers_tip_min`
# * max => `smokers_tip_max`
# * mean => `smokers_tip_mean`
# * median => `smokers_tip_median`

# %%
smokers_tip_min= smokers_df.tip.min()
smokers_tip_max= smokers_df.tip.max()
smokers_tip_mean= smokers_df.tip.mean()
smokers_tip_median= smokers_df.tip.median()

# %% [markdown]
# Let's output the results in the same format.
#
# Make the same dataframe containing the measures of central tendency for smokers as we did for whole dataset. Then output it.

# %%
smokers_values = [smokers_tip_min, smokers_tip_max, smokers_tip_mean, smokers_tip_median]

smokers_values = map(lambda x: round(x, 4), smokers_values)

smokers_mct = pd.DataFrame(smokers_values, index=['min', 'max', 'mean', 'median'])

smokers_mct
# Out:
#               0
# min      1.0000
# max     10.0000
# mean     3.0087
# median   3.0000

# %% [markdown]
# ##### **🚭 Non-smokers**

# %% [markdown]
# Now repeat it for non-smokers. Use the following variables:
#
# * min => `non_smokers_tip_min`
# * max => `non_smokers_tip_max`
# * mean => `non_smokers_tip_mean`
# * median => `non_smokers_tip_median`

# %%
non_smokers_tip_min= non_smokers_df.tip.min()
non_smokers_tip_max= non_smokers_df.tip.max()
non_smokers_tip_mean= non_smokers_df.tip.mean()
non_smokers_tip_median= non_smokers_df.tip.median()

# %% [markdown]
# Make the same dataframe containing the measures of central tendency for non-smokers as we did for whole dataset. Then output it.

# %%
non_smokers_values = [non_smokers_tip_min, non_smokers_tip_max, non_smokers_tip_mean, non_smokers_tip_median]

non_smokers_values = map(lambda x: round(x, 4), non_smokers_values)

non_smokers_mct = pd.DataFrame(non_smokers_values, index=['min', 'max', 'mean', 'median'])

non_smokers_mct
# Out:
#              0
# min     1.0000
# max     9.0000
# mean    2.9919
# median  2.7400

# %% [markdown]
# ##### **📝 Conclusion**

# %% [markdown]
# Let's show the retrieved results together (we already have the code written for you 😉):

# %%
all_vals_dict = {
    'Common': {'min': common_tip_min, 'max': common_tip_max, 'mean': common_tip_mean, 'median': common_tip_median},
    'Smokers': {'min': smokers_tip_min, 'max': smokers_tip_max, 'mean': smokers_tip_mean, 'median': smokers_tip_median},
    'Non-smokers': {'min': non_smokers_tip_min, 'max': non_smokers_tip_max, 'mean': non_smokers_tip_mean, 'median': non_smokers_tip_median}
}

# Make a dataframe
all_mct = pd.DataFrame(all_vals_dict)
# Output the dataframe
all_mct
# Out:
#            Common   Smokers  Non-smokers
# min      1.000000   1.00000     1.000000
# max     10.000000  10.00000     9.000000
# mean     2.998279   3.00871     2.991854
# median   2.900000   3.00000     2.740000

# %% [markdown]
# **Insights based on measures of central tendency comparison:**

# %% [markdown]
# ---
# 1. Insight 1: Smokers tend to give slightly higher tips than non-smokers. However, the difference of only 0.02 is minimal, so while smokers may have a slight inclination toward tipping more, this difference may not be practically significant.
# 2. Insight 2: The higher median for smokers suggests that their typical tipping behavior (the “middle” of the dataset) tends to be a bit more generous than that of non-smokers. This could indicate that smokers consistently tip slightly more, not just on average but across a wider range of scenarios.

# %% [markdown]
# **General conclusion:**

# %% [markdown]
# ---
# Both mean and median measures suggest a modest trend of smokers tipping more than non-smokers, with the median showing a more noticeable difference. While not drastic, these central tendency measures imply that smokers might have a slightly more generous tipping pattern in public catering environments.

# %% [markdown]
# #### **Look at histograms**

# %% [markdown]
# As we already discussed on the last lecture, there are a lot of cases, when comparing the measures of central tendency is not enough.
#
# This is because they only show the most typical values. However, the way data is distributed is equally important. There are situations where measures of central tendency are exactly the same, but due to different distributions, it is incorrect to say that the datasets are similar.

# %% [markdown]
# ##### **🌏 Whole dataset tips histogram**

# %% [markdown]
# Plot the histogram for the whole dataset tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#74b9ff`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Whole dataset tip values`
# * Gridlines: `show`

# %%
plt.figure(figsize=(15, 5))
plt.hist(df.tip, bins= 50, color= '#74b9ff' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Whole dataset tip values')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **🚬 Smokers tips histogram**

# %% [markdown]
# Plot the histogram for smokers tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#ff7675`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Smokers tip values`
# * Gridlines: `show`

# %%
plt.figure(figsize=(15, 5))
plt.hist(smokers_df.tip, bins= 50, color= '#ff7675' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Smokers tip values')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **🚭 Non-smokers tips histogram**

# %% [markdown]
# Plot the histogram for non-smokers tips distribution.
#
# <u>Use the following settings:</u>
# * Size: `15 x 5`
# * Color: `#55efc4`
# * X-axis label: `Tip value`
# * Y-axis label: `Frequency`
# * Chart title: `Non-smokers tip values`
# * Gridlines: `show`

# %%
plt.figure(figsize=(15, 5))
plt.hist(non_smokers_df.tip, bins= 50, color= '#ff7675' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Non-smokers tip values')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### **⭐ Extra-task with a higher difficulty**

# %% [markdown]
# Plot all 3 charts in a row in the same cell:

# %%
#Use subplot
fig, axis = plt.subplots(1, 3, figsize=(15, 5))
axis[0].hist(df.tip, bins=5, color="#74b9ff")
axis[0].set_title('Whole dataset tip values')

axis[1].hist(smokers_df.tip, bins=5, color="#ff7675")
axis[1].set_title('Smokers tip values')

axis[2].hist(non_smokers_df.tip, bins=5, color="#55efc4")
axis[2].set_title('Non-smokers tip values')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **📝 Conclusion**

# %% [markdown]
# **Insights based on distribution comparison:**
#
# ---
# General Tip Behavior: Across all groups, most customers leave low tips, with a sharp decrease in frequency as the tip amount increases.
# Smokers vs. Non-smokers: While both groups exhibit similar patterns, smokers seem to have a marginally higher occurrence of larger tips than non-smokers. This could indicate different tipping behaviors influenced by factors like group dynamics or social habits.
#
# **General conclusion:**
#
# ---
# The data shows that low tips dominate across all groups. The slightly higher tips among smokers may warrant further investigation to explore underlying causes, such as group sizes, dining experience, or spending habits.

# %% [markdown]
# ### **👨👩 Do males give more tips?**

# %% [markdown]
# Perform the same steps based on the column **sex**.

# %% [markdown]
# ####  **Central tendency**

# %%
#Create a new dataframe smokers_df containing only info about female customers.
female= df[df.sex== 'Female']
#Calculate measures of central tendency of female customers
f_min= female.tip.min()
f_max= female.tip.max()
f_mean= female.tip.mean()
f_median= female.tip.median()

#Create a new dataframe smokers_df containing only info about male customers.
male= df[df.sex== 'Male']
#Calculate measures of central tendency of male customers
m_min= male.tip.min()
m_max= male.tip.max()
m_mean= male.tip.mean()
m_median= male.tip.median()

#Calculate measures of central tendency for the whole dataset
common_tip_min= df.tip.min()
common_tip_max= df.tip.max()
common_tip_mean= df.tip.mean()
common_tip_median= df.tip.median()

all_vals_dict = {
    'Common': {'min': common_tip_min, 'max': common_tip_max, 'mean': common_tip_mean, 'median': common_tip_median},
    'Female': {'min': f_min, 'max': f_max, 'mean': f_mean, 'median': f_median},
    'Male': {'min': m_min, 'max': m_max, 'mean': m_mean, 'median': m_median}
}
# Make a dataframe
all_mct = pd.DataFrame(all_vals_dict)
# Output the dataframe
all_mct
# Out:
#            Common    Female       Male
# min      1.000000  1.000000   1.000000
# max     10.000000  6.500000  10.000000
# mean     2.998279  2.833448   3.089618
# median   2.900000  2.750000   3.000000

# %% [markdown]
# #### **Histogram**

# %%
#Plot the histogram for whole dataset tips distribution.
plt.figure(figsize=(15, 5))
plt.hist(df.tip, bins= 50, color= '#74b9ff' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Whole dataset tip values')
plt.grid(True)
plt.show()

# %%
#Plot the histogram for female customers tips distribution.
plt.figure(figsize=(15, 5))
plt.hist(female.tip, bins= 50, color= '#ff7675' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Female tip values')
plt.grid(True)
plt.show()

# %%
#Plot the histogram for male customers tips distribution.
plt.figure(figsize=(15, 5))
plt.hist(male.tip, bins= 50, color= '#ff7675' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Male tip values')
plt.grid(True)
plt.show()

# %%
#Use subplot to show distribution comparison
fig, axis = plt.subplots(1, 3, figsize=(15, 5))
axis[0].hist(df.tip, bins=5, color="#74b9ff")
axis[0].set_title('Whole dataset tip values')

axis[1].hist(female.tip, bins=5, color="#ff7675")
axis[1].set_title('Female tip values')

axis[2].hist(male.tip, bins=5, color="#55efc4")
axis[2].set_title('Male tip values')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Insight and Conclusion**

# %% [markdown]
# **Insights based on measures of central tendency comparison and distribution comparison:**
#
# ---
# 1. **Range of Tips:**
#    - Both males and females have a minimum tip value of 1.
#    - The maximum tip for males is 10, while for females, it is 6.5. This suggests that males tend to leave larger maximum tips compared to females.
#
# 2. **Average Tips:**
#    - The mean tip for males is **3.09**, while for females, it is **2.83**. This indicates that, on average, males give slightly higher tips than females.
#
# 3. **Median Tips:**
#    - The median tip for males is **3.0**, compared to **2.75** for females. This confirms that males generally tip slightly more even when considering the central tendency.
#
# 4. **Distribution Shape:**
#    - For both genders, the majority of tip values are concentrated between 1 and 3 units, with fewer instances of higher tips. However, males show a longer tail towards higher tip values, indicating a greater tendency for larger tips.

# %% [markdown]
# **General conclusion:**
#
# ---
# Yes, **males tend to give slightly more tips than females** based on the data. The higher mean, median, and maximum tip values for males support this conclusion. However, the difference is not drastic, and the overall tip distribution for both genders is still predominantly in the lower range (1–3 units).

# %% [markdown]
# ### **📆 Do weekends bring more tips?**

# %% [markdown]
# Perform the same steps based on the column **day**.

# %% [markdown]
# ####Central tendency

# %%
weekdays= ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']
weekday_df= df[df['day'].isin(weekdays)]
weekday_min= weekday_df.tip.min()
weekday_max= weekday_df.tip.max()
weekday_mean= weekday_df.tip.mean()
weekday_median= weekday_df.tip.median()

weekends= ['Sat','Sun']
weekend_df= df[df['day'].isin(weekends)]
weekend_min= weekend_df.tip.min()
weekend_max= weekend_df.tip.max()
weekend_mean= weekend_df.tip.mean()
weekend_median= weekend_df.tip.median()

common_tip_min= df.tip.min()
common_tip_max= df.tip.max()
common_tip_mean= df.tip.mean()
common_tip_median= df.tip.median()

all_vals_dict = {
    'Common': {'min': common_tip_min, 'max': common_tip_max, 'mean': common_tip_mean, 'median': common_tip_median},
    'Weekdays': {'min': weekday_min, 'max': weekday_max, 'mean': weekday_mean, 'median': weekday_median},
    'Weekends': {'min': weekend_min, 'max': weekend_max, 'mean': weekend_mean, 'median': weekend_median}
}

# Make a dataframe
all_mct = pd.DataFrame(all_vals_dict)
# Output the dataframe
all_mct
# Out:
#            Common  Weekdays   Weekends
# min      1.000000  1.000000   1.000000
# max     10.000000  4.730000  10.000000
# mean     2.998279  2.734737   3.115276
# median   2.900000  3.000000   3.000000

# %% [markdown]
# #### Histogram

# %%
plt.figure(figsize=(15, 5))
plt.hist(weekday_df.tip, bins= 40, color= '#B1D690' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Weekdays tip values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.hist(weekend_df.tip, bins= 40, color= '#FFA24C' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Weekend tip values')
plt.grid(True)
plt.show()

# %%
fig, axis = plt.subplots(1, 3, figsize=(15, 5))
axis[0].hist(df.tip, bins=10, color="#74b9ff")
axis[0].set_title('Whole dataset tip values')

axis[1].hist(weekday_df.tip, bins=10, color="#B1D690")
axis[1].set_title('Weekdays tip values')

axis[2].hist(weekend_df.tip, bins=10, color="#FF77B7")
axis[2].set_title('Weekend tip values')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insight and Conclusion

# %% [markdown]
# **Insights:**
#
# ---
#
# 1. **All Tips:**
#    - Tips range from **1 to 10**.
#    - Most tips are small, with an average (mean) of **2.99** and a middle value (median) of **2.9**.
#
# 2. **Tips on Weekdays (Mon-Fri):**
#    - Tips are smaller, with the highest being **4.73**.
#    - The average tip is **2.73**, which is lower than the overall average.
#    - Most tips are close to **3.0**.
#
# 3. **Tips on Weekends (Sat-Sun):**
#    - Tips are bigger, with some going up to **10.0**.
#    - The average is **3.12**, higher than on weekdays.
#    - Most tips are still around **3.0**, but there’s more variety and bigger tips on weekends.
#
# **General conclusions:**
#
# ---
# - **People tip more on weekends than weekdays.**
# - Weekends see a bigger range of tips, meaning some customers are more generous.
#
# **Practical implications:**
#
# ---
# - Higher Tips on Weekends: Customers give bigger tips on weekends than weekdays, so weekends are a better time for earning tips.
# - Planning for Weekends: Restaurants can prepare for higher tipping by having more staff or offering better service during weekends to make the most of it.

# %% [markdown]
# ### **🕑 Do dinners bring more tips?**

# %% [markdown]
# Perform the same steps based on the column **time**.

# %% [markdown]
# #### Central tendenncy

# %%
dinner_df= df[df.time== 'Dinner']
dinner_min= dinner_df.tip.min()
dinner_max= dinner_df.tip.max()
dinner_mean= dinner_df.tip.mean()
dinner_median= dinner_df.tip.median()


lunch_df= df[df.time== 'Lunch']
lunch_min= lunch_df.tip.min()
lunch_max= lunch_df.tip.max()
lunch_mean= lunch_df.tip.mean()
lunch_median= lunch_df.tip.median()


common_tip_min= df.tip.min()
common_tip_max= df.tip.max()
common_tip_mean= df.tip.mean()
common_tip_median= df.tip.median()

all_vals_dict = {
    'Common': {'min': common_tip_min, 'max': common_tip_max, 'mean': common_tip_mean, 'median': common_tip_median},
    'Dinner': {'min': dinner_min, 'max': dinner_max, 'mean': dinner_mean, 'median': dinner_median},
    'Lunch': {'min': lunch_min, 'max': lunch_max, 'mean': lunch_mean, 'median': lunch_median}
}
# Make a dataframe
all_mct = pd.DataFrame(all_vals_dict)
# Output the dataframe
all_mct
# Out:
#            Common    Dinner     Lunch
# min      1.000000   1.00000  1.250000
# max     10.000000  10.00000  6.700000
# mean     2.998279   3.10267  2.728088
# median   2.900000   3.00000  2.250000

# %% [markdown]
# #### Histogram

# %%
##Plot the histogram for tip distribution at dinner time
plt.figure(figsize=(15, 5))
plt.hist(dinner_df.tip, bins= 40, color= '#B4D6CD' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Dinner tip values')
plt.grid(True)
plt.show()
#Plot the histogram for tip distribution at lunch time
plt.figure(figsize=(15, 5))
plt.hist(lunch_df.tip, bins= 40, color= '#FFDA76' )
plt.xlabel('Tip value')
plt.ylabel('Frequency')
plt.title('Lunch tip values')
plt.grid(True)
plt.show()

# %%
#Compare tip distribution using subplot
fig, axis = plt.subplots(1, 3, figsize=(15, 5))
axis[0].hist(df.tip, bins=5, color="#FF8C9E")
axis[0].set_title('Whole dataset tip values')

axis[1].hist(dinner_df.tip, bins=5, color="#B4D6CD")
axis[1].set_title('Dinner tip values')

axis[2].hist(lunch_df.tip, bins=5, color="#FFDA76")
axis[2].set_title('Lunch tip values')
plt.tight_layout()

# %% [markdown]
# #### Insight and Conclusion

# %% [markdown]
# **Insights on Tips for Dinner vs. Lunch:**
#
# ---
#
# 1. **All Tips (Common):**
#    - Tips range from **1 to 10**.
#    - The average tip is **2.99**, and most tips are around **2.9**.
#
# 2. **Dinner Tips:**
#    - Tips range from **1 to 10**, just like the overall dataset.
#    - The average tip is **3.10**, which is slightly higher than the overall average.
#    - Most tips are around **3.0**.
#
# 3. **Lunch Tips:**
#    - Tips are smaller, ranging from **1.25 to 6.7**.
#    - The average tip is **2.73**, which is lower than the overall and dinner averages.
#    - Most tips are around **2.25**, lower than for dinner.
#
# **Conclusions:**
#
# ---
# - **Dinner customers tip more than lunch customers.**
# - Lunch tips have a smaller range and tend to be lower overall.
#
# **Practical Suggestions:**
#
# ---
# - Focus on **dinner service** to maximize tips.
# - Consider strategies to increase lunch tips, like promotions or improved service.
